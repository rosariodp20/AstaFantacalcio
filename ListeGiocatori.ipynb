# %%
# FUNZIONI SEPARATE PER CIASCUN RUOLO

from openpyxl import load_workbook    #Importo questa libreria che mi permette di leggere i file Excel


def ListaPortieri():
    
    Listone=load_workbook(filename='Quotazioni_Fantacalcio.xlsx')   #Apro il file excel in modalità lettura
    sheet=Listone['Tutti']       #Mi posiziono sul foglio "Tutti" del file excel che ho aperto
    
    Lista_Port=list()              #Creo una lista vuota in cui andrò ad appendere tutti i portieri
    
    #sheet[C2].value                          #Modo per selezionare il contenuto di un cella Excel
    #sheet.cell(row=5, column=2).value        #Modo alternativo per selezionare il contenuto di una cella Excel
    
    #Vado a scorrere tutto il file Excel e appendo tutti i portieri a Lista_Port()
    
    i=3
    while i<600:
        B='B'+str(i)
        C='C'+str(i)
        if sheet[B].value=='P':
            Lista_Port.append(sheet[C].value)
        i=i+1
    return Lista_Port


def ListaDifensori():
    
    Listone=load_workbook(filename='Quotazioni_Fantacalcio.xlsx')
    sheet=Listone['Tutti']
    
    Lista_Dif=list()
    
    i=3
    while i<600:
        B='B'+str(i)
        C='C'+str(i)
        if sheet[B].value=='D':
            Lista_Dif.append(sheet[C].value)
        i=i+1
    return Lista_Dif


def ListaCentrocampisti():
    
    Listone=load_workbook(filename='Quotazioni_Fantacalcio.xlsx')
    sheet=Listone['Tutti']
    
    Lista_Centr=list()
    
    i=3
    while i<600:
        B='B'+str(i)
        C='C'+str(i)
        if sheet[B].value=='C':
            Lista_Centr.append(sheet[C].value)
        i=i+1
            
    return Lista_Centr


def ListaAttaccanti():
    
    Listone=load_workbook(filename='Quotazioni_Fantacalcio.xlsx')
    sheet=Listone['Tutti']
    
    Lista_Att=list()
    
    i=3
    while i<600:
        B='B'+str(i)
        C='C'+str(i)
        if sheet[B].value=='A':
            Lista_Att.append(sheet[C].value)
        i=i+1
            
    return Lista_Att

#Nel main dovrò scrivere questo per ottenere le liste:
#Attaccanti=ListaAttaccanti()
#Centrocampisti=ListaCentrocampisti()
#Difensori=ListaDifensori()
#Portieri=ListaPortieri()

# %%
# FUNZIONE UNICA PER TUTTI I RUOLI

from openpyxl import load_workbook


def ListaGiocatori():
    
    Listone=load_workbook(filename='Quotazioni_Fantacalcio.xlsx')
    sheet=Listone['Tutti']
    
    Lista_Port=list()
    Lista_Dif=list()
    Lista_Centr=list()
    Lista_Att=list()
    
    i=3
    while i<600:
        B='B'+str(i)
        C='C'+str(i)
        if sheet[B].value=='P':
            Lista_Port.append(sheet[C].value)
        elif sheet[B].value=='D':
            Lista_Dif.append(sheet[C].value)
        elif sheet[B].value=='C':
            Lista_Centr.append(sheet[C].value)
        elif sheet[B].value=='A':
            Lista_Att.append(sheet[C].value)
        i=i+1
    return Lista_Port,Lista_Dif,Lista_Centr,Lista_Att

#Se utilizzo funzione unica ho in output una tupla: nella posizione "0" ho una lista di portieri, nella posizione "1" ho
#una lista di difensori, nella posizione "2" ho una lista di centrocampisti e nella posizione "3" ho una lista di attaccanti

#Nel main dovrò utilizzare questi comandi per salvare le varie liste separatamente
#A=ListaGiocatori()
#Portieri=A[0]
#Difensori=A[1]
#Centrocampisti=A[2]
#Attaccanti=A[3]

# %%
#FUNZIONI SEPARATE PER CIASCUN RUOLO CHE MI RESTITUISCONO UNA LISTA [NOMEGIOCATORE,SQUADRA]

from openpyxl import load_workbook


def ListaPortieriSquadra():
    
    Listone=load_workbook(filename='Quotazioni_Fantacalcio.xlsx')
    sheet=Listone['Tutti']
    
    Lista_Port=list()
    
    i=3
    while i<600:
        B='B'+str(i)
        C='C'+str(i)
        D='D'+str(i)
        if sheet[B].value=='P':
            Lista_Port.append([sheet[C].value,sheet[D].value])
        i=i+1
    return Lista_Port


def ListaDifensoriSquadra():
    
    Listone=load_workbook(filename='Quotazioni_Fantacalcio.xlsx')
    sheet=Listone['Tutti']
    
    Lista_Dif=list()
    
    i=3
    while i<600:
        B='B'+str(i)
        C='C'+str(i)
        D='D'+str(i)
        if sheet[B].value=='D':
            Lista_Dif.append([sheet[C].value,sheet[D].value])
        i=i+1
    return Lista_Dif


def ListaCentrocampistiSquadra():
    
    Listone=load_workbook(filename='Quotazioni_Fantacalcio.xlsx')
    sheet=Listone['Tutti']
    
    Lista_Centr=list()
    
    i=3
    while i<600:
        B='B'+str(i)
        C='C'+str(i)
        D='D'+str(i)
        if sheet[B].value=='C':
            Lista_Centr.append([sheet[C].value,sheet[D].value])
        i=i+1
            
    return Lista_Centr


def ListaAttaccantiSquadra():
    
    Listone=load_workbook(filename='Quotazioni_Fantacalcio.xlsx')
    sheet=Listone['Tutti']
    
    Lista_Att=list()
    
    i=3
    while i<600:
        B='B'+str(i)
        C='C'+str(i)
        D='D'+str(i)
        if sheet[B].value=='A':
            Lista_Att.append([sheet[C].value,sheet[D].value])
        i=i+1
            
    return Lista_Att

#Nel main dovrò utilizzare questi comandi:
Attaccanti=ListaAttaccantiSquadra()
print(Attaccanti)
#Centrocampisti=ListaCentrocampistiSquadra()
#Difensori=ListaDifensoriSquadra()
#Portieri=ListaPortieriSquadra()
# Out:
# [['RONALDO', 'Juventus'], ['LUKAKU', 'Inter'], ['MURIEL', 'Atalanta'], ['MARTINEZ L.', 'Inter'], ['INSIGNE', 'Napoli'], ['IMMOBILE', 'Lazio'], ['IBRAHIMOVIC', 'Milan'], ['BERARDI', 'Sassuolo'], ['BELOTTI', 'Torino'], ['CAPUTO', 'Sassuolo'], ['ZAPATA D.', 'Atalanta'], ['JOAO PEDRO', 'Cagliari'], ['SIMY', 'Crotone'], ['VLAHOVIC', 'Fiorentina'], ['LOZANO', 'Napoli'], ['MERTENS', 'Napoli'], ['ILICIC', 'Atalanta'], ['MORATA', 'Juventus'], ['SANCHEZ', 'Inter'], ['RAFAEL LEAO', 'Milan'], ['DESTRO', 'Genoa'], ['MESSIAS', 'Crotone'], ['QUAGLIARELLA', 'Sampdoria'], ['CAICEDO', 'Lazio'], ['DZEKO', 'Roma'], ['MAYORAL', 'Roma'], ['NZOLA', 'Spezia'], ['PETAGNA', 'Napoli'], ['BARROW', 'Bologna'], ['KEITA B.', 'Sampdoria'], ['REBIC', 'Milan'], ['ORSOLINI', 'Bologna'], ['CAPRARI', 'Benevento'], ['GYASI', 'Spezia'], ['SHOMURODOV', 'Genoa'], ['SIMEONE', 'Cagliari'], ['DYBALA', 'Juventus'], ['OSIMHEN', 'Napoli'], ['VERDE', 'Spezia'], ['RIBERY', 'Fiorentina'], ['BOGA', 'Sassuolo'], ['DEFREL', 'Sassuolo']
# ...
